# %%
# Let's import the needed packages
import xarray as xr
import cartopy.crs as ccrs
import matplotlib.pyplot as plt

# Data path
sst_data_path = 'data/sst.mnmean.nc'
mslp_data_path = 'data/mslp_coarse.nc'

# Upload the data under a xr array format
sst_ds = xr.open_dataset(sst_data_path)
mslp_ds = xr.open_dataset(mslp_data_path)

# Data Structure
print(sst_ds)
print(mslp_ds)
# Out:
# <xarray.Dataset> Size: 123MB
# Dimensions:    (lat: 180, lon: 360, time: 475, nbnds: 2)
# Coordinates:
#   * lat        (lat) float32 720B 89.5 88.5 87.5 86.5 ... -87.5 -88.5 -89.5
#   * lon        (lon) float32 1kB 0.5 1.5 2.5 3.5 4.5 ... 356.5 357.5 358.5 359.5
#   * time       (time) datetime64[ns] 4kB 1981-12-01 1982-01-01 ... 2021-06-01
# Dimensions without coordinates: nbnds
# Data variables:
#     sst        (time, lat, lon) float32 123MB ...
#     time_bnds  (time, nbnds) datetime64[ns] 8kB ...
# Attributes:
#     title:          NOAA Optimum Interpolation (OI) SST V2
#     Conventions:    CF-1.0
#     history:        Wed Apr  6 13:47:45 2005: ncks -d time,0,278 SAVEs/sst.mn...
#     comments:       Data described in  Reynolds, R.W., N.A. Rayner, T.M.\nSmi...
#     platform:       Model
#     source:         NCEP Climate Modeling Branch
#     institution:    National Centers for Environmental Prediction
#     References:     https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2....
#     dataset_title:  NOAA Optimum Interpolation (OI) SST V2
#     source_url:     http://www.emc.ncep.noaa.gov/research/cmb/sst_analysis/
# <xarray.Dataset> Size: 138MB
# Dimensions:    (latitude: 181, longitude: 360, time: 531)
# Coordinates:
#   * latitude   (latitude) float32 724B 90.0 89.0 88.0 87.0 ... -88.0 -89.0 -90.0
#   * longitude  (longitude) float32 1kB 0.0 1.0 2.0 3.0 ... 357.0 358.0 359.0
#   * time       (time) datetime64[ns] 4kB 1979-01-01 1979-02-01 ... 2023-03-01
# Data variables:
#     msl        (time, latitude, longitude) float32 138MB ...
# Attributes:
#     Conventions:                 CF-1.6
#     NCO:                         netCDF Operators version 4.9.1 (Homepage = h...
#     title:                       ERA5 reanalysis
#     data_type:                   1xmonthly fields analysis
#     grid_resolution_in_degrees:  0.25
#     source:                      credit: ECMWF, COPERNICUS Climate Change Ser...
#     history:                     Thu Nov 30 14:28:43 2023: ncks -d longitude,...

# %%
# Plot the dimensions and attributes of the data 
sst_ds.info()
mslp_ds.info()
# Out:
# xarray.Dataset {
# dimensions:
# 	lat = 180 ;
# 	lon = 360 ;
# 	time = 475 ;
# 	nbnds = 2 ;
#
# variables:
# 	float32 lat(lat) ;
# 		lat:units = degrees_north ;
# 		lat:long_name = Latitude ;
# 		lat:actual_range = [ 89.5 -89.5] ;
# 		lat:standard_name = latitude ;
# 		lat:axis = Y ;
# 		lat:coordinate_defines = center ;
# 	float32 lon(lon) ;
# 		lon:units = degrees_east ;
# 		lon:long_name = Longitude ;
# 		lon:actual_range = [  0.5 359.5] ;
# 		lon:standard_name = longitude ;
# 		lon:axis = X ;
# 		lon:coordinate_defines = center ;
# 	float32 sst(time, lat, lon) ;
# 		sst:long_name = Monthly Mean of Sea Surface Temperature ;
# 		sst:unpacked_valid_range = [-5. 40.] ;
# 		sst:actual_range = [-1.7999996 35.56862  ] ;
# 		sst:units = degC ;
# 		sst:precision = 2 ;
# 		sst:var_desc = Sea Surface Temperature ;
# 		sst:dataset = NOAA Optimum Interpolation (OI) SST V2 ;
# 		sst:level_desc = Surface ;
# 		sst:statistic = Mean ;
# 		sst:parent_stat = Weekly Mean ;
# 		sst:standard_name = sea_surface_temperature ;
# 		sst:cell_methods = time: mean (monthly from weekly values interpolated to daily) ;
# 		sst:valid_range = [-500 4000] ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = Time ;
# 		time:actual_range = [66443. 80870.] ;
# 		time:delta_t = 0000-01-00 00:00:00 ;
# 		time:avg_period = 0000-01-00 00:00:00 ;
# 		time:prev_avg_period = 0000-00-07 00:00:00 ;
# 		time:standard_name = time ;
# 		time:axis = T ;
# 		time:bounds = time_bnds ;
# 	datetime64[ns] time_bnds(time, nbnds) ;
# 		time_bnds:long_name = Time Boundaries ;
#
# // global attributes:
# 	:title = NOAA Optimum Interpolation (OI) SST V2 ;
# 	:Conventions = CF-1.0 ;
# 	:history = Wed Apr  6 13:47:45 2005: ncks -d time,0,278 SAVEs/sst.mnmean.nc sst.mnmean.nc
# Created 10/2002 by RHS ;
# 	:comments = Data described in  Reynolds, R.W., N.A. Rayner, T.M.
# Smith, D.C. Stokes, and W. Wang, 2002: An Improved In Situ and Satellite
# SST Analysis for Climate, J. Climate ;
# 	:platform = Model ;
# 	:source = NCEP Climate Modeling Branch ;
# 	:institution = National Centers for Environmental Prediction ;
# 	:References = https://www.psl.noaa.gov/data/gridded/data.noaa.oisst.v2.html ;
# 	:dataset_title = NOAA Optimum Interpolation (OI) SST V2 ;
# 	:source_url = http://www.emc.ncep.noaa.gov/research/cmb/sst_analysis/ ;
# }xarray.Dataset {
# dimensions:
# 	latitude = 181 ;
# 	longitude = 360 ;
# 	time = 531 ;
#
# variables:
# 	float32 latitude(latitude) ;
# 		latitude:units = degrees_north ;
# 		latitude:long_name = latitude ;
# 	float32 longitude(longitude) ;
# 		longitude:units = degrees_east ;
# 		longitude:long_name = longitude ;
# 	float32 msl(time, latitude, longitude) ;
# 		msl:units = Pa ;
# 		msl:long_name = Mean sea level pressure ;
# 		msl:standard_name = air_pressure_at_mean_sea_level ;
# 		msl:level_desc = surface ;
# 	datetime64[ns] time(time) ;
# 		time:long_name = time ;
#
# // global attributes:
# 	:Conventions = CF-1.6 ;
# 	:NCO = netCDF Operators version 4.9.1 (Homepage = http://nco.sf.net, Code = http://github.com/nco/nco) ;
# 	:title = ERA5 reanalysis ;
# 	:data_type = 1xmonthly fields analysis ;
# 	:grid_resolution_in_degrees = 0.25 ;
# 	:source = credit: ECMWF, COPERNICUS Climate Change Service data, available from the ESPRI/IPSL data center ;
# 	:history = Thu Nov 30 14:28:43 2023: ncks -d longitude,0,-1,4 -d latitude,0,-1,4 mslp_era5.nc mslp_coarse.nc
# Thu Nov 30 13:56:29 2023: ncrcat /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1979/msl.1979.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1980/msl.1980.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1981/msl.1981.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1982/msl.1982.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1983/msl.1983.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1984/msl.1984.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1985/msl.1985.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1986/msl.1986.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1987/msl.1987.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1988/msl.1988.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1989/msl.1989.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1990/msl.1990.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1991/msl.1991.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1992/msl.1992.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1993/msl.1993.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1994/msl.1994.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1995/msl.1995.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1996/msl.1996.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1997/msl.1997.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1998/msl.1998.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/1999/msl.1999.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2000/msl.2000.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2001/msl.2001.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2002/msl.2002.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2003/msl.2003.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2004/msl.2004.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2005/msl.2005.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2006/msl.2006.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2007/msl.2007.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2008/msl.2008.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2009/msl.2009.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2010/msl.2010.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2011/msl.2011.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2012/msl.2012.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2013/msl.2013.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2014/msl.2014.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2015/msl.2015.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2016/msl.2016.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2017/msl.2017.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2018/msl.2018.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2019/msl.2019.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2020/msl.2020.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2021/msl.2021.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2022/msl.2022.asme5.GLOBAL_025.nc /bdd/ERA5/NETCDF/GLOBAL_025/1xmonthly/AN_SF/2023/msl.2023.asme5.GLOBAL_025.nc msl.nc
# Tue Jun 21 07:41:43 2022: ncatted -a history,global,d,, /scratch/ms/fr/asn/ERA5/AN_SF/1979/msl.1979.asme5.GLOBAL_025.nc ;
# }
